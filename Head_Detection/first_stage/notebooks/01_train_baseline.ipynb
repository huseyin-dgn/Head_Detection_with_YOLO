# %%
import torch, time
print(torch.cuda.get_device_name(0))
print("VRAM GB:", torch.cuda.get_device_properties(0).total_memory/1024**3)

print("CUDA available:", torch.cuda.is_available())
# Out:
# NVIDIA GeForce RTX 3060 Laptop GPU
# VRAM GB: 5.99951171875
# CUDA available: True

# %% [markdown]
# ----

# %% [markdown]
# ## İlk model eğitim bloğu

# %% [markdown]
# ----

# %%
from pathlib import Path
root = Path(r"C:\Users\hdgn5\OneDrive\Masaüstü\Head Detection\scut_head_yolo_rebalanced")
print((root/"images/val").exists(), root/"images/val")
print((root/"labels/val").exists(), root/"labels/val")
# Out:
# True C:\Users\hdgn5\OneDrive\Masaüstü\Head Detection\scut_head_yolo_rebalanced\images\val
# True C:\Users\hdgn5\OneDrive\Masaüstü\Head Detection\scut_head_yolo_rebalanced\labels\val

# %%
from pathlib import Path
import os, sys

sys.path = [p for p in sys.path if p and p != r"C:\HysoExpect"]

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from src.train import train

run_dir = train(r"C:\Users\hdgn5\OneDrive\Masaüstü\Head Detection\head_yolo_project\configs\train_baseline.yaml")
print("RUN DIR:", run_dir)
# Out:
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203  Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
